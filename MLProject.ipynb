# %% [markdown]
# **Intro to ML - Project 1.**

# %% [markdown]
# Name: Jagruthi Reddy Ghanapati

# %% [markdown]
# UB# 50560478

# %% [markdown]
# **Disabling the warning, if any:**

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Opening Data as file:**

# %%
with open ('adult.data') as file:
    for line in file:
        if not line.strip():
            continue
        print(line)
# Out:
# 39, State-gov, 77516, Bachelors, 13, Never-married, Adm-clerical, Not-in-family, White, Male, 2174, 0, 40, United-States, <=50K
#
# 50, Self-emp-not-inc, 83311, Bachelors, 13, Married-civ-spouse, Exec-managerial, Husband, White, Male, 0, 0, 13, United-States, <=50K
#
# 38, Private, 215646, HS-grad, 9, Divorced, Handlers-cleaners, Not-in-family, White, Male, 0, 0, 40, United-States, <=50K
#
# 53, Private, 234721, 11th, 7, Married-civ-spouse, Handlers-cleaners, Husband, Black, Male, 0, 0, 40, United-States, <=50K
#
# 28, Private, 338409, Bachelors, 13, Married-civ-spouse, Prof-specialty, Wife, Black, Female, 0, 0, 40, Cuba, <=50K
#
# 37, Private, 284582, Masters, 14, Married-civ-spouse, Exec-managerial, Wife, White, Female, 0, 0, 40, United-States, <=50K
#
# 49, Private, 160187, 9th, 5, Married-spouse-absent, Other-service, Not-in-family, Black, Female, 0, 0, 16, Jamaica, <=50K
#
# ...

# %% [markdown]
# **Giving the column names:**

# %%
column_names=['age','workclass','fnlwgt', 'education','education-num','marital-status','occupation','relationship','race','sex','capital-gain','capital-loss','hours-per-week','native-country','income']

# %% [markdown]
# **1.Loading the data:**

# %%
adult_data = pd.read_csv(r"C:\Users\ghana\dataset_adult\adult.data", header=None, names=column_names)

# %% [markdown]
# **2.Printing the structure of the data:**

# %%
adult_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   32561 non-null  int64
#  5   marital-status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  native-country  32561 non-null  object
#  14  income          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
adult_data.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object')

# %%
adult_data.dtypes
# Out:
# age                int64
# workclass         object
# fnlwgt             int64
# education         object
# education-num      int64
# marital-status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# capital-gain       int64
# capital-loss       int64
# hours-per-week     int64
# native-country    object
# income            object
# dtype: object

# %%
adult_data.describe()
# Out:
#                 age        fnlwgt  education-num  capital-gain  capital-loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours-per-week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
adult_data.head()
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country  income
# 0          2174             0              40   United-States   <=50K
# ...

# %% [markdown]
# **Checking if any null values in data:**

# %%
adult_data.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# income            0
# dtype: int64

# %% [markdown]
# **Printing unique values in each column of data:**

# %%
for column in adult_data.columns:
    unique_values = adult_data[column].unique()
    print(f"Unique values in column '{column}':")
    print(unique_values)
    print("\n" + "-"*50 + "\n")
# Out:
# Unique values in column 'age':
# [39 50 38 53 28 37 49 52 31 42 30 23 32 40 34 25 43 54 35 59 56 19 20 45
#  22 48 21 24 57 44 41 29 18 47 46 36 79 27 67 33 76 17 55 61 70 64 71 68
#  66 51 58 26 60 90 75 65 77 62 63 80 72 74 69 73 81 78 88 82 83 84 85 86
#  87]
#
# --------------------------------------------------
#
# Unique values in column 'workclass':
# [' State-gov' ' Self-emp-not-inc' ' Private' ' Federal-gov' ' Local-gov'
#  ' ?' ' Self-emp-inc' ' Without-pay' ' Never-worked']
#
# --------------------------------------------------
#
# Unique values in column 'fnlwgt':
# [ 77516  83311 215646 ...  34066  84661 257302]
#
# --------------------------------------------------
#
# Unique values in column 'education':
# [' Bachelors' ' HS-grad' ' 11th' ' Masters' ' 9th' ' Some-college'
#  ' Assoc-acdm' ' Assoc-voc' ' 7th-8th' ' Doctorate' ' Prof-school'
#  ' 5th-6th' ' 10th' ' 1st-4th' ' Preschool' ' 12th']
#
# --------------------------------------------------
#
# ...

# %% [markdown]
# **3.Handling Missing Values:**
# - Dropping the rows with ' ?'

# %%
# Assuming your DataFrame is named `adult_test_encoded`
adult_data = adult_data[adult_data['workclass'] != ' ?']
adult_data = adult_data[adult_data['occupation'] != ' ?']
adult_data = adult_data[adult_data['native-country'] != ' ?']

# %%
adult_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 30162 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             30162 non-null  int64
#  1   workclass       30162 non-null  object
#  2   fnlwgt          30162 non-null  int64
#  3   education       30162 non-null  object
#  4   education-num   30162 non-null  int64
#  5   marital-status  30162 non-null  object
#  6   occupation      30162 non-null  object
#  7   relationship    30162 non-null  object
#  8   race            30162 non-null  object
#  9   sex             30162 non-null  object
#  10  capital-gain    30162 non-null  int64
#  11  capital-loss    30162 non-null  int64
#  12  hours-per-week  30162 non-null  int64
#  13  native-country  30162 non-null  object
#  14  income          30162 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %% [markdown]
# **Removing the extra space in each entry of income column:**

# %%
adult_data['income'] = adult_data['income'].str.strip()

# %%
adult_data['income'].unique()
# Out:
# array(['<=50K', '>50K'], dtype=object)

# %% [markdown]
# **Creating a list of categorical columns:**

# %%
categorical_columns=['workclass','education', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'native-country', 'income']

# %% [markdown]
# **3.Encoding the categorical columns:**

# %%
adult_data_encoded = pd.get_dummies(adult_data, categorical_columns)
print(adult_data_encoded)
# Out:
#        age  fnlwgt  education-num  capital-gain  capital-loss  hours-per-week  \
# 0       39   77516             13          2174             0              40
# 1       50   83311             13             0             0              13
# 2       38  215646              9             0             0              40
# 3       53  234721              7             0             0              40
# 4       28  338409             13             0             0              40
# ...    ...     ...            ...           ...           ...             ...
# 32556   27  257302             12             0             0              38
# 32557   40  154374              9             0             0              40
# 32558   58  151910              9             0             0              40
# 32559   22  201490              9             0             0              20
# 32560   52  287927              9         15024             0              40
#
# ...

# %% [markdown]
# **Printing the structure of Encoded data:**

# %%
adult_data_encoded.head()
# Out:
#    age  fnlwgt  education-num  capital-gain  capital-loss  hours-per-week  \
# 0   39   77516             13          2174             0              40
# 1   50   83311             13             0             0              13
# 2   38  215646              9             0             0              40
# 3   53  234721              7             0             0              40
# 4   28  338409             13             0             0              40
#
#    workclass_ Federal-gov  workclass_ Local-gov  workclass_ Private  \
# 0                   False                 False               False
# 1                   False                 False               False
# 2                   False                 False                True
# 3                   False                 False                True
# 4                   False                 False                True
#
#    workclass_ Self-emp-inc  ...  native-country_ Scotland  \
# ...

# %%
adult_data_encoded.columns
# Out:
# Index(['age', 'fnlwgt', 'education-num', 'capital-gain', 'capital-loss',
#        'hours-per-week', 'workclass_ Federal-gov', 'workclass_ Local-gov',
#        'workclass_ Private', 'workclass_ Self-emp-inc',
#        ...
#        'native-country_ Scotland', 'native-country_ South',
#        'native-country_ Taiwan', 'native-country_ Thailand',
#        'native-country_ Trinadad&Tobago', 'native-country_ United-States',
#        'native-country_ Vietnam', 'native-country_ Yugoslavia', 'income_<=50K',
#        'income_>50K'],
#       dtype='object', length=106)

# %% [markdown]
# **4.Exploratory Data Analysis:**

# %%
adult_data_encoded.corr()
# Out:
#                                     age    fnlwgt  education-num  \
# age                            1.000000 -0.076511       0.043526
# fnlwgt                        -0.076511  1.000000      -0.044992
# education-num                  0.043526 -0.044992       1.000000
# capital-gain                   0.080154  0.000422       0.124416
# capital-loss                   0.060165 -0.009750       0.079646
# ...                                 ...       ...            ...
# native-country_ United-States  0.016259 -0.083390       0.127207
# native-country_ Vietnam       -0.017775 -0.010761      -0.010953
# native-country_ Yugoslavia     0.000657  0.005707      -0.001661
# income_<=50K                  -0.241998  0.008957      -0.335286
# income_>50K                    0.241998 -0.008957       0.335286
#
#                                capital-gain  capital-loss  hours-per-week  \
# age                                0.080154      0.060165        0.101599
# ...

# %% [markdown]
# - **Plot to identify distribution of Population by Age:**

# %%
plt.figure(figsize=(10, 6))
sns.histplot(adult_data['age'], bins=20, kde=False, color='orange')
plt.title('Distribution of Population by Age')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# - **Plot to identify distribution of income by gender:**

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='sex', hue='income', data=adult_data)
plt.title('Distribution of Income by Gender')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.legend(title='Income', loc='upper right')
plt.show()

# %% [markdown]
# - **Plot to identify distribution of income by education:**

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x='education', hue='income', data=adult_data, palette='coolwarm')
plt.title('Distribution of Income by Education', fontsize=16)
plt.xlabel('Education Level', fontsize=14)
plt.ylabel('Count of Individuals', fontsize=14)
plt.legend(title='Income', loc='upper right')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.xticks(rotation=90) 
plt.show()

# %% [markdown]
# - **Plot to identify proportion distribution across occupation levels:**

# %%
occupation = pd.crosstab(adult_data.occupation, adult_data.income)
occupation_proportion = occupation.div(occupation.sum(axis=1), axis=0)
occupation_proportion.sort_values(by='>50K', ascending=False, inplace=True)
ax = occupation_proportion.plot(kind='barh', stacked=True, figsize=(10, 8), color=['lightcoral', 'lightblue'])
ax.set_title('Proportion Distribution Across Occupation Levels', fontsize=16)
ax.set_xlabel('Proportion of Population', fontsize=14)
ax.set_ylabel('Occupation Level', fontsize=14)
ax.legend(title='Income', loc='upper right')
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# - **Plot to identify age distribution of people in top occupation:**

# %%
top_occupation = occupation_proportion.index[0]
top_occupation_data = adult_data[adult_data['occupation'] == top_occupation]
plt.figure(figsize=(12, 6))
sns.histplot(top_occupation_data['age'], bins=20, kde=True, color='lightblue')
plt.title(f'Age Distribution of People in Top Occupation: {top_occupation}', fontsize=16)
plt.xlabel('Age', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# - **Plot to identify sex distribution in Top Occupation:**

# %%
occupation_income = pd.crosstab(adult_data['occupation'], adult_data['income'])
occupation_proportion = occupation_income.div(occupation_income.sum(axis=1), axis=0)
top_occupation = occupation_proportion['>50K'].idxmax()
top_occupation_data = adult_data[adult_data['occupation'] == top_occupation]
plt.figure(figsize=(8, 6))
sns.countplot(x='sex', data=top_occupation_data, palette='coolwarm')
plt.title(f'Sex Distribution in Top Occupation: {top_occupation}', fontsize=16)
plt.xlabel('Sex', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.tight_layout()
plt.show()

# %% [markdown]
# - **Plot to identify age distribution of individuals earning more than 50k:**

# %%
high_income_data = adult_data[adult_data['income'] == '>50K']
min_age = high_income_data['age'].min()
plt.figure(figsize=(12, 6))
sns.histplot(high_income_data['age'], bins=20, kde=True, color='lightgreen')
plt.axvline(min_age, color='red', linestyle='--', label=f'Youngest Age: {min_age}')
plt.title('Age Distribution of Individuals Earning More than 50K', fontsize=16)
plt.xlabel('Age', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.legend(title='Income >50K', loc='upper right')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# - **Plot to identify sex distribution in top age and least age in top occupation:**

# %%
occupation_income = pd.crosstab(adult_data['occupation'], adult_data['income'])
occupation_proportion = occupation_income.div(occupation_income.sum(axis=1), axis=0)
top_occupation = occupation_proportion['>50K'].idxmax()
top_occupation_data = adult_data[(adult_data['occupation'] == top_occupation) & (adult_data['income'] == '>50K')]
top_age = top_occupation_data['age'].max()
least_age = top_occupation_data['age'].min()
top_age_data = top_occupation_data[top_occupation_data['age'] == top_age]
least_age_data = top_occupation_data[top_occupation_data['age'] == least_age]
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
sns.countplot(x='sex', data=top_age_data, palette='coolwarm')
plt.title(f'Sex Distribution in Top Age ({top_age}) for {top_occupation}', fontsize=14)
plt.xlabel('Sex')
plt.ylabel('Count')
plt.subplot(1, 2, 2)
sns.countplot(x='sex', data=least_age_data, palette='coolwarm')
plt.title(f'Sex Distribution in Least Age ({least_age}) for {top_occupation}', fontsize=14)
plt.xlabel('Sex')
plt.ylabel('Count')
plt.tight_layout()
plt.show()

# %% [markdown]
# - **Plot to identify education distribution of top and least age individuals earning income>50k:**

# %%
high_income_data = adult_data[adult_data['income'] == '>50K']
min_age = high_income_data['age'].min()
max_age = high_income_data['age'].max()
min_age_education = high_income_data[high_income_data['age'] == min_age]['education']
max_age_education = high_income_data[high_income_data['age'] == max_age]['education']
min_max_education = pd.concat([min_age_education, max_age_education])
age_category = ['Youngest'] * len(min_age_education) + ['Oldest'] * len(max_age_education)
min_max_education_df = pd.DataFrame({'Education': min_max_education, 'Age Category': age_category})
plt.figure(figsize=(12, 6))
sns.countplot(x='Education', hue='Age Category', data=min_max_education_df, palette='coolwarm')
plt.title('Education Distribution of Youngest and Oldest Individuals Earning More than 50K', fontsize=16)
plt.xlabel('Education Level', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# - **Plot to identify race distribution in top occupation:**

# %%
occupation_income = pd.crosstab(adult_data['occupation'], adult_data['income'])
occupation_proportion = occupation_income.div(occupation_income.sum(axis=1), axis=0)
top_occupation = occupation_proportion['>50K'].idxmax()
top_occupation_data = adult_data[adult_data['occupation'] == top_occupation]
plt.figure(figsize=(10, 6))
sns.countplot(x='race', data=top_occupation_data, palette='Set2')
plt.title(f'Race Distribution in Top Occupation: {top_occupation}', fontsize=16)
plt.xlabel('Race', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.xticks(rotation=45) 
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# - **Plot to identify education distribution in top race:**

# %%
top_race = top_occupation_data['race'].value_counts().idxmax()
top_race_data = top_occupation_data[top_occupation_data['race'] == top_race]
plt.figure(figsize=(10, 6))
sns.countplot(x='education', data=top_race_data, palette='viridis')
plt.title(f'Education Distribution in Top Race: {top_race}', fontsize=16)
plt.xlabel('Education Level', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.xticks(rotation=45) 
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# - **Plot to identify age distribution in different workclasses for individuals earning income>50k:**

# %%
high_income_data = adult_data[adult_data['income'] == '>50K']
plt.figure(figsize=(12, 6))
sns.boxplot(x='workclass', y='age', data=high_income_data, palette='coolwarm')
plt.title('Age Distribution by Work Class for Individuals Earning More than 50K', fontsize=16)
plt.xlabel('Work Class', fontsize=14)
plt.ylabel('Age', fontsize=14)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# - **Plot to identify distribution of income by education:**

# %%
high_income_data = adult_data[adult_data['income'] == '>50K']
occupation_count = high_income_data.groupby(['workclass', 'occupation']).size().reset_index(name='count')
workclass_occupation_counts = occupation_count.groupby('workclass')['occupation'].nunique().reset_index()
top_workclass = workclass_occupation_counts.sort_values(by='occupation', ascending=False)
plt.figure(figsize=(12, 6))
sns.barplot(x='occupation', y='workclass', data=top_workclass, palette='viridis')
plt.title('Number of Unique Occupations Earning >50K by Work Class', fontsize=16)
plt.xlabel('Number of Unique Occupations', fontsize=14)
plt.ylabel('Work Class', fontsize=14)
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# - **Plot to identify education distribution in top workclass:**

# %%
high_income_data = adult_data[adult_data['income'] == '>50K']
occupation_count = high_income_data.groupby(['workclass', 'occupation']).size().reset_index(name='count')
workclass_occupation_counts = occupation_count.groupby('workclass')['occupation'].nunique().reset_index()
top_workclass = workclass_occupation_counts.sort_values(by='occupation', ascending=False).iloc[0]['workclass']
top_workclass_data = high_income_data[high_income_data['workclass'] == top_workclass]
plt.figure(figsize=(12, 6))
sns.countplot(x='education', data=top_workclass_data, palette='pastel')
plt.title(f'Education Distribution in {top_workclass} for Individuals Earning >50K', fontsize=16)
plt.xlabel('Education Level', fontsize=14)
plt.ylabel('Count of Individuals', fontsize=14)
plt.xticks(rotation=90) 
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Referencing cleaned data as training data:**

# %%
train=adult_data

# %%
train.head()
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country income
# 0          2174             0              40   United-States  <=50K
# ...

# %% [markdown]
# Dropping the education column since the education-num column already provides a numerical representation of education levels. Encoding the education column would unnecessarily increase the number of columns without adding significant value. Additionally, given the low correlation between income and education, removing this column is justified.

# %%
train.drop(columns='education',inplace=True)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 30162 entries, 0 to 32560
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             30162 non-null  int64
#  1   workclass       30162 non-null  object
#  2   fnlwgt          30162 non-null  int64
#  3   education-num   30162 non-null  int64
#  4   marital-status  30162 non-null  object
#  5   occupation      30162 non-null  object
#  6   relationship    30162 non-null  object
#  7   race            30162 non-null  object
#  8   sex             30162 non-null  object
#  9   capital-gain    30162 non-null  int64
#  10  capital-loss    30162 non-null  int64
#  11  hours-per-week  30162 non-null  int64
#  12  native-country  30162 non-null  object
#  13  income          30162 non-null  object
# dtypes: int64(6), object(8)
# memory usage: 3.5+ MB

# %%
cat_cols=['workclass','marital-status','occupation','relationship','race','sex','native-country','income']

# %% [markdown]
# **Encoding the training data:**

# %%
train_encoded = pd.get_dummies(train, columns=cat_cols, drop_first=True)

# %%
train_encoded.columns
# Out:
# Index(['age', 'fnlwgt', 'education-num', 'capital-gain', 'capital-loss',
#        'hours-per-week', 'workclass_ Local-gov', 'workclass_ Private',
#        'workclass_ Self-emp-inc', 'workclass_ Self-emp-not-inc',
#        'workclass_ State-gov', 'workclass_ Without-pay',
#        'marital-status_ Married-AF-spouse',
#        'marital-status_ Married-civ-spouse',
#        'marital-status_ Married-spouse-absent',
#        'marital-status_ Never-married', 'marital-status_ Separated',
#        'marital-status_ Widowed', 'occupation_ Armed-Forces',
#        'occupation_ Craft-repair', 'occupation_ Exec-managerial',
#        'occupation_ Farming-fishing', 'occupation_ Handlers-cleaners',
#        'occupation_ Machine-op-inspct', 'occupation_ Other-service',
#        'occupation_ Priv-house-serv', 'occupation_ Prof-specialty',
#        'occupation_ Protective-serv', 'occupation_ Sales',
#        'occupation_ Tech-support', 'occupation_ Transport-moving',
# ...

# %% [markdown]
# **Loading adult.test data:**

# %%
adult_test=pd.read_csv(r"C:\Users\ghana\adult.test", header=None, names=column_names)

# %%
adult_test.head()
# Out:
#                     age   workclass    fnlwgt      education  education-num  \
# 0  |1x3 Cross validator         NaN       NaN            NaN            NaN
# 1                    25     Private  226802.0           11th            7.0
# 2                    38     Private   89814.0        HS-grad            9.0
# 3                    28   Local-gov  336951.0     Assoc-acdm           12.0
# 4                    44     Private  160323.0   Some-college           10.0
#
#         marital-status          occupation relationship    race    sex  \
# 0                  NaN                 NaN          NaN     NaN    NaN
# 1        Never-married   Machine-op-inspct    Own-child   Black   Male
# 2   Married-civ-spouse     Farming-fishing      Husband   White   Male
# 3   Married-civ-spouse     Protective-serv      Husband   White   Male
# 4   Married-civ-spouse   Machine-op-inspct      Husband   Black   Male
#
#    capital-gain  capital-loss  hours-per-week  native-country   income
# ...

# %%
adult_test=pd.read_csv(r"C:\Users\ghana\adult.test", header=None, skiprows = 1, names=column_names)

# %%
adult_test.head()
# Out:
#    age   workclass  fnlwgt      education  education-num       marital-status  \
# 0   25     Private  226802           11th              7        Never-married
# 1   38     Private   89814        HS-grad              9   Married-civ-spouse
# 2   28   Local-gov  336951     Assoc-acdm             12   Married-civ-spouse
# 3   44     Private  160323   Some-college             10   Married-civ-spouse
# 4   18           ?  103497   Some-college             10        Never-married
#
#            occupation relationship    race      sex  capital-gain  \
# 0   Machine-op-inspct    Own-child   Black     Male             0
# 1     Farming-fishing      Husband   White     Male             0
# 2     Protective-serv      Husband   White     Male             0
# 3   Machine-op-inspct      Husband   Black     Male          7688
# 4                   ?    Own-child   White   Female             0
#
#    capital-loss  hours-per-week  native-country   income
# ...

# %% [markdown]
# **Checking for null values:**

# %%
adult_test.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# income            0
# dtype: int64

# %% [markdown]
# **Printing unique values in each column:**

# %%
for columns in adult_test.columns:
    unique_test_values = adult_test[columns].unique()
    print(f"Unique values in columns '{columns}':")
    print(unique_test_values)
    print("\n" + "-"*50 + "\n")
# Out:
# Unique values in columns 'age':
# [25 38 28 44 18 34 29 63 24 55 65 36 26 58 48 43 20 37 40 72 45 22 23 54
#  32 46 56 17 39 52 21 42 33 30 47 41 19 69 50 31 59 49 51 27 57 61 64 79
#  73 53 77 80 62 35 68 66 75 60 67 71 70 90 81 74 78 82 83 85 76 84 89 88
#  87]
#
# --------------------------------------------------
#
# Unique values in columns 'workclass':
# [' Private' ' Local-gov' ' ?' ' Self-emp-not-inc' ' Federal-gov'
#  ' State-gov' ' Self-emp-inc' ' Without-pay' ' Never-worked']
#
# --------------------------------------------------
#
# Unique values in columns 'fnlwgt':
# [226802  89814 336951 ... 349230 321403  83891]
#
# --------------------------------------------------
#
# Unique values in columns 'education':
# [' 11th' ' HS-grad' ' Assoc-acdm' ' Some-college' ' 10th' ' Prof-school'
#  ' 7th-8th' ' Bachelors' ' Masters' ' Doctorate' ' 5th-6th' ' Assoc-voc'
#  ' 9th' ' 12th' ' 1st-4th' ' Preschool']
#
# --------------------------------------------------
#
# ...

# %% [markdown]
# **Handling Missing Values:**
# - Dropping the rows with ' ?', implementing the same cleaning steps that were used on original data that was referred as trainin.

# %%
adult_test = adult_test[adult_test['workclass'] != ' ?']
adult_test = adult_test[adult_test['occupation'] != ' ?']
adult_test = adult_test[adult_test['native-country'] != ' ?']

# %%
adult_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 15060 entries, 0 to 16280
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             15060 non-null  int64
#  1   workclass       15060 non-null  object
#  2   fnlwgt          15060 non-null  int64
#  3   education       15060 non-null  object
#  4   education-num   15060 non-null  int64
#  5   marital-status  15060 non-null  object
#  6   occupation      15060 non-null  object
#  7   relationship    15060 non-null  object
#  8   race            15060 non-null  object
#  9   sex             15060 non-null  object
#  10  capital-gain    15060 non-null  int64
#  11  capital-loss    15060 non-null  int64
#  12  hours-per-week  15060 non-null  int64
#  13  native-country  15060 non-null  object
#  14  income          15060 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 1.8+ MB

# %% [markdown]
# **Referring adult_test as test data:**

# %%
test=adult_test

# %%
test.head()
# Out:
#    age   workclass  fnlwgt      education  education-num       marital-status  \
# 0   25     Private  226802           11th              7        Never-married
# 1   38     Private   89814        HS-grad              9   Married-civ-spouse
# 2   28   Local-gov  336951     Assoc-acdm             12   Married-civ-spouse
# 3   44     Private  160323   Some-college             10   Married-civ-spouse
# 5   34     Private  198693           10th              6        Never-married
#
#            occupation    relationship    race    sex  capital-gain  \
# 0   Machine-op-inspct       Own-child   Black   Male             0
# 1     Farming-fishing         Husband   White   Male             0
# 2     Protective-serv         Husband   White   Male             0
# 3   Machine-op-inspct         Husband   Black   Male          7688
# 5       Other-service   Not-in-family   White   Male             0
#
#    capital-loss  hours-per-week  native-country   income
# ...

# %% [markdown]
# **Dropping the education column from test data as well:**

# %%
test.drop(columns='education',inplace=True)

# %% [markdown]
# **Encoding the categorical columns of test data:**

# %%
test_encoded=pd.get_dummies(test,columns=cat_cols, drop_first=True)

# %%
test_encoded.columns
# Out:
# Index(['age', 'fnlwgt', 'education-num', 'capital-gain', 'capital-loss',
#        'hours-per-week', 'workclass_ Local-gov', 'workclass_ Private',
#        'workclass_ Self-emp-inc', 'workclass_ Self-emp-not-inc',
#        'workclass_ State-gov', 'workclass_ Without-pay',
#        'marital-status_ Married-AF-spouse',
#        'marital-status_ Married-civ-spouse',
#        'marital-status_ Married-spouse-absent',
#        'marital-status_ Never-married', 'marital-status_ Separated',
#        'marital-status_ Widowed', 'occupation_ Armed-Forces',
#        'occupation_ Craft-repair', 'occupation_ Exec-managerial',
#        'occupation_ Farming-fishing', 'occupation_ Handlers-cleaners',
#        'occupation_ Machine-op-inspct', 'occupation_ Other-service',
#        'occupation_ Priv-house-serv', 'occupation_ Prof-specialty',
#        'occupation_ Protective-serv', 'occupation_ Sales',
#        'occupation_ Tech-support', 'occupation_ Transport-moving',
# ...

# %% [markdown]
# **Replacing the income column name with the name that matches with the encoded training data:**

# %%
test_encoded.columns = test_encoded.columns.str.replace('income_ >50K.', 'income_>50K', regex=False)

# %%
test_encoded.columns
# Out:
# Index(['age', 'fnlwgt', 'education-num', 'capital-gain', 'capital-loss',
#        'hours-per-week', 'workclass_ Local-gov', 'workclass_ Private',
#        'workclass_ Self-emp-inc', 'workclass_ Self-emp-not-inc',
#        'workclass_ State-gov', 'workclass_ Without-pay',
#        'marital-status_ Married-AF-spouse',
#        'marital-status_ Married-civ-spouse',
#        'marital-status_ Married-spouse-absent',
#        'marital-status_ Never-married', 'marital-status_ Separated',
#        'marital-status_ Widowed', 'occupation_ Armed-Forces',
#        'occupation_ Craft-repair', 'occupation_ Exec-managerial',
#        'occupation_ Farming-fishing', 'occupation_ Handlers-cleaners',
#        'occupation_ Machine-op-inspct', 'occupation_ Other-service',
#        'occupation_ Priv-house-serv', 'occupation_ Prof-specialty',
#        'occupation_ Protective-serv', 'occupation_ Sales',
#        'occupation_ Tech-support', 'occupation_ Transport-moving',
# ...

# %% [markdown]
# **Checking if any columns mismatch is happening between training and test:**

# %%
train_columns = train_encoded.columns
test_columns = test_encoded.columns
columns_to_drop = train_columns.difference(test_columns)
print("Columns that are in training but not in test:\n", columns_to_drop)
# Out:
# Columns that are in training but not in test:
#  Index([], dtype='object')

# %% [markdown]
# **5.Applying predictive modeling to the data to predict whether an individual earns more than
# $50K a year.**

# %% [markdown]
# **Setting the target variable:**

# %%
X_train = train_encoded.drop('income_>50K', axis=1)
y_train = train_encoded['income_>50K'] 
X_test = test_encoded.drop('income_>50K', axis=1)
y_test = test_encoded['income_>50K']

# %% [markdown]
# - **Random Forrest Classifier:**

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred = model.predict(X_test)
print(f"Accuracy: {accuracy_score(y_test, y_pred)}")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.850265604249668
#               precision    recall  f1-score   support
#
#        False       0.88      0.93      0.90     11360
#         True       0.73      0.61      0.67      3700
#
#     accuracy                           0.85     15060
#    macro avg       0.81      0.77      0.79     15060
# weighted avg       0.84      0.85      0.85     15060

# %% [markdown]
# - **Logistic Regression:**

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

logistic_model = LogisticRegression(max_iter=1000)
logistic_model.fit(X_train, y_train)
X_test_aligned = X_test.reindex(columns=X_train.columns, fill_value=0)
y_pred = logistic_model.predict(X_test_aligned)
print(f"Accuracy: {accuracy_score(y_test, y_pred)}")
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.8371181938911022
# Confusion Matrix:
#  [[10492   868]
#  [ 1585  2115]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#        False       0.87      0.92      0.90     11360
#         True       0.71      0.57      0.63      3700
#
#     accuracy                           0.84     15060
#    macro avg       0.79      0.75      0.76     15060
# weighted avg       0.83      0.84      0.83     15060

# %% [markdown]
# - **AdaBoost Classifier:**

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score

param_grid = {
    'n_estimators': [50, 100, 200],
    'learning_rate': [0.01, 0.1, 1.0],
}
grid_search = GridSearchCV(AdaBoostClassifier(), param_grid, cv=3, scoring='accuracy')
grid_search.fit(X_train, y_train)
best_model = grid_search.best_estimator_
y_pred = best_model.predict(X_test)
print(f"Accuracy: {accuracy_score(y_test, y_pred)}")
# Out:
# Accuracy: 0.8628818061088978

# %% [markdown]
# - **XGBoost:**

# %%
from xgboost import XGBClassifier

xgb = XGBClassifier()
xgb.fit(X_train, y_train)
y_pred_xgb = xgb.predict(X_test)
xgb_accuracy = accuracy_score(y_test, y_pred_xgb)
print(f"XGBoost Accuracy: {xgb_accuracy}")
# Out:
# XGBoost Accuracy: 0.8676626826029217

# %% [markdown]
# **Summary:**
# - After evaluating various models, the Gradient Boosting Classifier emerged as the best choice for predicting whether an individual earns more than $50K a year, achieving an accuracy of about 87%.
